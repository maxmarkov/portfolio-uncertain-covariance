# %% [markdown]
# # Appendix C: Dependence between volatility and correlation coefficient
#
# In this section, we calculated the average volatility and average correlation coefficient for major stock indexes on a monthly scale for the years 2008, 2016, 2020, and 2022. We then plotted these values on scatter plots below. The constituents of the index were taken from the first day of each respective year. This result can be used to model the covariance matrix in the stressed regime $\Sigma$ s in equivariant and equicorrelation approximation.
#
#
# ### 1. All indices separately
#
# #### US
#
# <img src="figures/monthly/SPX_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/CCMP_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/RIY_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/RTY_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/RAY_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/RLV_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/RLG_volatility_vs_correlation_monthly_means.png">
#
# #### S&P 500 sectors
#
# <img src="figures/monthly/S5COND_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/S5CONS_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/S5ENRS_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/S5FINL_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/S5HLTH_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/S5INFT_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/S5MATR_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/S5RLST_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/S5TELS_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/S5UTIL_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/S5INDU_volatility_vs_correlation_monthly_means.png">
#
# #### Europe
#
# <img src="figures/monthly/DAX_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/CAC_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/BEL20_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/UKX_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/IBEX_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/KFX_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/OMX_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/SMI_volatility_vs_correlation_monthly_means.png">
#
# #### APAC
#
# <img src="figures/monthly/AS51_volatility_vs_correlation_monthly_means.png">
#
# #### Japan
#
# <img src="figures/monthly/NKY_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/TPX_volatility_vs_correlation_monthly_means.png">
#
#
# #### BRIC
#
# <img src="figures/monthly/IBOV_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/NIFTY_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/MXIN_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/SHCOMP_volatility_vs_correlation_monthly_means.png">
#
# <img src="figures/monthly/SHSZ300_volatility_vs_correlation_monthly_means.png">
#
# ### 2. All indices together
#
# <img src="figures/monthly/all-indice_volatility_vs_correlation_monthly_means.png"/>
#
# ### 3. All indices by year
#
# <img src="figures/monthly/all_indices_volatility_vs_correlation_monthly_means_2008.png" width="500"/>
#
# <img src="figures/monthly/all_indices_volatility_vs_correlation_monthly_means_2016.png" width="500"/>
#
# <img src="figures/monthly/all_indices_volatility_vs_correlation_monthly_means_2020.png" width="500"/>
#
# <img src="figures/monthly/all_indices_volatility_vs_correlation_monthly_means_2022.png" width="500"/>
#
# #### Huber regression coefficients
#
# |  index    |   slope    | intercept     |
# |:---:|:------:|:-------:|
# | US|  | |
# | CCMP| 0.002159 | 0.037878|
# | RIY | 0.003447 | 0.132864|
# | RTY | 0.004263 | 0.091931|
# | RLV | 0.003286 | 0.232391|
# | RAY | 0.004193 | 0.127431|
# | SPX | 0.003401 | 0.168945|
# | NBI | 0.002828 | 0.096777|
# | RLG | -0.000302| 0.327449|
# | S&P 500|  | |
# | S5COND| 0.003764| 0.235765|
# | S5CONS| 0.003485| 0.311703|
# | S5ENRS| 0.003780| 0.422933|
# | S5FINL| 0.004032| 0.429415|
# | S5HLTH| 0.003454| 0.336169|
# | S5INFT| 0.005012| 0.289568|
# | S5MATR| 0.004429| 0.314090|
# | S5RLST| 0.001686| 0.562081|
# | S5TELS| 0.003371| 0.320119|
# | S5UTIL| 0.000282| 0.625587|
# | S5INDU| 0.004632| 0.378368|
# | Europe |  | |
# | BEL20| 0.005987| 0.159943|
# | CAC  | 0.002676| 0.334654|
# | DAX  | 0.002900| 0.352742|
# | IBEX | 0.005854| 0.173340|
# | KFX  | 0.006507| 0.128498|
# | OMX  | 0.002007| 0.332009|
# | SMI  | 0.004549| 0.322233|
# | UKX  | 0.003899| 0.204774|
# | APAC |  | |
# | AS51 | 0.002416| 0.154542|
# | Japan|  | |
# | NKY  | 0.004782| 0.251314|
# | TPX  | 0.004820| 0.145084|
# | BRIC|  | |
# | IBOV | 0.003735| 0.194038|
# | RTSI$| 0.002136| 0.151959|
# | NIFTY| 0.004274| 0.168294|
# | MXIN | 0.004911| 0.127383|
# | SHCOMP | 0.009223| -0.023746|
# | SHSZ300| 0.009007| 0.033359|

# %%
import numpy as np
